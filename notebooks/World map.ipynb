# %%
import pandas as pd
import numpy as np
import dash_bootstrap_components as dbc

import dash
dash.__version__
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output,State

import plotly.express as px
import plotly.graph_objects as go
from plotly import tools

# %%
world_con=pd.read_csv('../data/processed/COVID_CRD.csv',sep=';')
world_con.head()
# Out:
#        COUNTRY CODE  Confirm cases  Deaths  Recovered   Active
# 0  Afghanistan  AFG         233861    1385      28016   8552.0
# 1      Albania  ALB        5667112     245       4184   3846.0
# 2      Algeria  DZA        3044940    1424      28874  10770.0
# 3      Andorra  AND        3582362      53        875    117.0
# 4       Angola  AGO         386054      94        814   1226.0

# %%
df_input_large=pd.read_csv('../data/processed/COVID_CRD.csv',sep=';')
df_input_large.head()
# Out:
#        COUNTRY CODE  Confirm cases  Deaths  Recovered   Active
# 0  Afghanistan  AFG         233861    1385      28016   8552.0
# 1      Albania  ALB        5667112     245       4184   3846.0
# 2      Algeria  DZA        3044940    1424      28874  10770.0
# 3      Andorra  AND        3582362      53        875    117.0
# 4       Angola  AGO         386054      94        814   1226.0

# %%
app = dash.Dash(__name__)



app.layout = html.Div([
    html.H1("World Map"),
    
    dcc.RadioItems(id = 'Items',
    options=[
        {'label': 'Confirmed', 'value': 'Confirm cases'},
        {'label': 'Death', 'value': 'Deaths'},
        {'label': 'Recovered', 'value': 'Recovered'}
    ],
    value='Death'
                ),
    
    dcc.Graph(id = "World_map",
            figure = px.choropleth(df, locations='CODE',
                            color= cases,
                            hover_name="COUNTRY",
                            projection='natural earth',
                            title='World map',
                            color_continuous_scale=px.colors.sequential.Plasma),

            figure.update_layout(title=dict(font=dict(size=28),x=0.5,xanchor='center'),
                          margin=dict(l=60, r=60, t=50, b=50))
    )
])

fig.show()
# Out:
#   File "<ipython-input-31-c286c81191ba>", line 25
#     figure.update_layout(title=dict(font=dict(size=28),x=0.5,xanchor='center'),
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
@app.callback(
    Output('World_map', 'figure'),
    [Input('Items', 'value')])

def World(cases):
    df = df_input_large
    
    fig = px.choropleth(df, locations='CODE',
                            color= cases,
                            hover_name="COUNTRY",
                            projection='natural earth',
                            title='World map',
                            color_continuous_scale=px.colors.sequential.Plasma)

    fig.update_layout(title=dict(font=dict(size=28),x=0.5,xanchor='center'),
                          margin=dict(l=60, r=60, t=50, b=50))
    
    
    
    return (fig)

# %%
if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
# Dash is running on http://127.0.0.1:4050/
#
# Dash is running on http://127.0.0.1:4050/
#
# Dash is running on http://127.0.0.1:4050/
#
# Dash is running on http://127.0.0.1:4050/
#
# Dash is running on http://127.0.0.1:4050/
#
# Dash is running on http://127.0.0.1:4050/
#
# Dash is running on http://127.0.0.1:4050/
#
# ...
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
# ...

# %%
fig = go.Figure(go.Choropleth(
                    locations = df['CODE'],
                    z = df[cases],
                    text = df['COUNTRY'],
                    colorscale = 'Blues',
                    autocolorscale=False,
                    reversescale=False,
                    marker_line_color='darkgray',
                    marker_line_width=0.5,
                    colorbar_title = 'Confirmed cases',
                    ))
